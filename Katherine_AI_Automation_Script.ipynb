# %% [markdown]
# <a href="https://colab.research.google.com/github/svrbasky/Katherine_AI/blob/main/Katherine_AI_Automation_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step 1 Get Top Amazon Books
#Step 2 Generate Script
#Step 3 Generate Video Avatar
#Step 4 Generate Music
#Step 5 Edit Video
#Step 6 Post Edited Video to Youtube

# %% [markdown]
# Install Dependencies

# %%
# !pip install snscrape                      #Scrape Amazon Book Reviews on Twitter
# !pip install vaderSentiment                #Identify the Most Positive Review
# !pip install openai                        #Generate 30 second video script
# !pip install pydub                         #Generate Background Music
# !pip install shotstack_sdk                 #Video Editing API

# %% [markdown]
# ## Step 1 - Get book information
#
# - Let's first scrape Tweets using the keyword "Machine Learning textbook Amazon"

# %%
import snscrape.modules.twitter as sntwitter
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

analyzer = SentimentIntensityAnalyzer()
limit= 10
tweets_list =[]
for tweet in sntwitter.TwitterSearchScraper("Machine Learning Textbook amazon").get_items():
    if len(tweets_list)== limit:
        break
    else:
        tweets_list.append([tweet.date, tweet.content, tweet.user.username, tweet.user.displayname, tweet.user.description,
        tweet.replyCount, tweet.retweetCount,tweet.likeCount , tweet.quoteCount, tweet.lang, tweet.source])
df = pd.DataFrame(tweets_list,columns=["date", "tweets", "username", "displayname", "description", "rpcounts",
                                        "retweetcounts", "likecounts", "quotecount", "languvage", "source"  ])
print(df)

# %% [markdown]
# - Now we can select 1 tweet to extract the book name and review from
# - If its positive enough (>60 percent sentiment score) we'll promote it

# %%
book_title = df.loc[0,"tweets"]
sentiment = analyzer.polarity_scores(book_title)
print(book_title)
print(sentiment)
# Out:
# Linear Algebra and Optimization for Machine Learning: A Textbook https://t.co/4asEdWYgmg #Amazon #datascience
# {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'compound': 0.5106}

# %% [markdown]
# ## Step 2 - Generate Script

# %%
import openai

openai.api_key = "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"

# "Summarize the item.description in two sentences".
prompt = "Summarize this in two sentences: " + book_title

book_summary = openai.Completion.create(
  model = "text-davinci-003",
  prompt = prompt,
  temperature = 1,
  max_tokens = 600,
  top_p = 1,
  frequency_penalty = 0,
  presence_penalty = 0
)

print(book_summary)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThis textbook provides an overview of linear algebra and optimization theory referenced in various fields of machine learning. It presents theoretical and practical insights into problem solving and optimization techniques used in modern artificial intelligence and deep learning."
#     }
#   ],
#   "created": 1677001102,
#   "id": "cmpl-6mQsoGzimrmgaFGzAosPUGDxTW4Ss",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 42,
#     "prompt_tokens": 40,
#     "total_tokens": 82
#   }
# }

# %% [markdown]
# ## Step 3 - Generate Explanatory Animations
#
# - Let's install manim, the math animation library in python by 3blue1brown on Youtube
# - This will take 2-3 minutes to install. its big. may require a runtime restart.
# - If you don't want to wait, go here: https://hub.ovh2.mybinder.org/user/manimcommunity-jupyter_examples-dr3u00vk/notebooks/First%20Steps%20with%20Manim.ipynb

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython==7.9.0
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [71.6 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# ...

# %% [markdown]
# Now let's ask OpenAI to generate us some manim code

# %%
import openai

openai.api_key = "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"

# "Summarize the item.description in two sentences".
prompt = "/* Create a short manim script in python to animate " + str(book_summary) + "*/"

manim_code = openai.Completion.create(
  model = "code-davinci-002",
  prompt = prompt,
  temperature = 1,
  max_tokens = 100,
  top_p = 1,
  frequency_penalty = 0,
  presence_penalty = 0
)


print(manim_code)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n// This is a compile time constant.\n// Warning: generated code that imports mllib.py cannot refer to this value in any way,\n// eg. with Scene(Text[\"ManiLang String Completion\"])), since the dependencies would then be\n// 'davinci-v3a.py', the string and 'mllib.py' and then Text wouldn't be resolvable due to missing context.\n// To work around this,"
#     }
#   ],
#   "created": 1677002405,
#   "id": "cmpl-6mRDpUY5QcNyjV2McHbCJ5f85svKj",
#   "model": "code-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 100,
#     "prompt_tokens": 214,
#     "total_tokens": 314
#   }
# }

# %% [markdown]
# unfortunately, they're still not that great at it. ChatGPT > GPT-3 at this by far. So we'll just type some in here to animate linear algebra.

# %%
# %manim -qm -v WARNING matrixTest

from manim import *
import numpy as np
class matrixTest(Scene):

	def construct(self):
		A = np.array([[-1, 5], [7, 11]])
		B = np.array([[2, 3], [-8, 0]])
		C = np.dot(A, B)

		stuff = VGroup(Matrix(A), Matrix(B), Matrix(C))
		matrixA = stuff[0]
		matrixB = stuff[1]
		matrixC = stuff[2]
		matrixA.height = 2.5
		matrixB.height = 2.5
		matrixA.color = PURPLE
		matrixB.color = RED
		Dot = Tex(".", color=WHITE, font_size = 200)
		Equals = Tex("=", color=WHITE, font_size = 100)
		bOpen = Tex("[", color=WHITE, font_size = 100)
		bClose = Tex("]", color=WHITE, font_size=100)
		bOpen1 = Tex("[", color=WHITE, font_size=200)
		bClose1 = Tex("]", color=WHITE, font_size=200)


		self.play(Write(matrixA))
		self.play(matrixA.animate.scale(1).to_corner(UP+LEFT*2))

		Dot.next_to(matrixA, RIGHT)
		self.play(Write(Dot))

		self.play(Write(matrixB))
		self.play(matrixB.animate.scale(1).next_to(Dot, RIGHT))

		Equals.next_to(matrixB, RIGHT)
		self.play(Write(Equals))

		matrixC.next_to(Equals)
		C_elements = VGroup(*matrixC)
		for i in C_elements[1:]:
			i.height = 2.5
			self.play(Write(i))
		C_elements = VGroup(*C_elements[0])
		A_rows = matrixA.get_rows()
		A = VGroup(A_rows[0], A_rows[0], A_rows[1], A_rows[1])
		B_columns = matrixB.get_columns()
		B = VGroup(B_columns[0], B_columns[1], B_columns[0], B_columns[1])

		for r, c, ans in zip(A.copy(), B.copy(), C_elements.copy()):
			_bOpen = bOpen.copy()
			_bClose = bClose.copy()
			_bOpen1 = bOpen1.copy()
			_bClose1 = bClose1.copy()
			_Dot = Dot.copy()
			_r = r.copy()
			_c = c.copy()
			_bOpen.next_to(matrixA, DOWN*3)
			self.play(Write(_bOpen))
			self.play(_r.set_color(BLUE).animate.next_to(_bOpen))
			_bClose.next_to(_r, RIGHT)
			self.play(Write(_bClose))
			_Dot.next_to(_bClose, RIGHT)
			self.play(Write(_Dot))
			_bOpen1.next_to(_Dot, RIGHT)
			self.play(Write(_bOpen1))
			self.play(_c.set_color(YELLOW).animate.next_to(_bOpen1))
			_bClose1.next_to(_c, RIGHT)
			self.play(Write(_bClose1))
			g = VGroup(_bOpen, _r, _bClose, _Dot, _bOpen1, _c, _bClose1)
			ans.font_size = 60
			ans.set_color(PURE_GREEN)
			self.play(Transform(g, ans))

		self.wait()
		self.play(Write(Text("Code in the desciption", font_size=80)))
		self.wait()
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-71-e1f76f529528> in <module>
# ----> 1 from manim import *
#       2 import numpy as np
#       3 class matrixTest(Scene):
#       4
#       5         def construct(self):
#
# /usr/local/lib/python3.8/dist-packages/manim/__init__.py in <module>
#       6 import pkg_resources
#       7
# ----> 8 __version__: str = pkg_resources.get_distribution(__name__).version
#       9
#      10
#
# /usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     464         dist = Requirement.parse(dist)
#     465     if isinstance(dist, Requirement):
# --> 466         dist = get_provider(dist)
#     467     if not isinstance(dist, Distribution):
#     468         raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# ...

# %% [markdown]
# ## Step 3 - Generate Video Avatar
#
# - Lets now generate a video avatar using D-ID
# - We can do this programatically to generate the video on the D ID server

# %%
#D-ID key YUdWc2JHOUFjMmx5WVdweVlYWmhiQzVqYjIwOlVzMlVLRkRKZGd1ZEVvdlYyUWNmbA==
#video avatar ource image https://i.imgur.com/rkDNaTq.png

import requests

url = "https://api.d-id.com/talks"

script = "Hey! It's your favorite AI teacher Katherine." + book_summary + "Buy it on Amazon now!"

payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "Sara"
        },
        "ssml": "false",
        "input": script
    },
    "config": {
        "fluent": "false",
        "pad_audio": "0.0"
    },
    "source_url": "https://i.imgur.com/rkDNaTq.png "
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik53ek53TmV1R3ptcFZTQjNVZ0J4ZyJ9.....gSO76mMdPY-5ceXl8lZY5fIP0_4cexGa7lIEQ9-6EVtwYUGbhN46Q5tk861Xfo0uAfzxhXhPlSYJ0o9hapmi2gikaMfqbJ1FuI-gmdg2ioJ_OlrNOehsjLES6bGRnRDctGlHuIyBNsuR0cwVcI55Dq2PXvd8XysCqgDVkwGu1eZxXP-F8WMLtYoEjI7ozyv5avFKlydeiGBjpiKrFve3ZOCRYYCPvtjUniDMo2jyLxosT5cwPzFb2JLYy53tzgYp0cPN9rfBIwyRDQUoBXT_6tCa-FE0JPUWTi-nrNbwqJEesZxVM9TL26I4I9yN5itK5qGfTo3DvEoJjGzZW9xLDw"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-baa9411e6039> in <module>
#       6 url = "https://api.d-id.com/talks"
#       7
# ----> 8 script = "Hey! It's your favorite AI teacher Katherine." + book_summary + "Buy it on Amazon now!"
#       9
#      10 payload = {
#
# NameError: name 'book_summary' is not defined

# %% [markdown]
# after generation, we can pull the video URL from the D-ID server

# %%
import requests

url = "https://api.d-id.com/talks?limit=100"

headers = {
    "accept": "application/json",
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik53ek53TmV1R3ptcFZTQjNVZ0J4ZyJ9.....gSO76mMdPY-5ceXl8lZY5fIP0_4cexGa7lIEQ9-6EVtwYUGbhN46Q5tk861Xfo0uAfzxhXhPlSYJ0o9hapmi2gikaMfqbJ1FuI-gmdg2ioJ_OlrNOehsjLES6bGRnRDctGlHuIyBNsuR0cwVcI55Dq2PXvd8XysCqgDVkwGu1eZxXP-F8WMLtYoEjI7ozyv5avFKlydeiGBjpiKrFve3ZOCRYYCPvtjUniDMo2jyLxosT5cwPzFb2JLYy53tzgYp0cPN9rfBIwyRDQUoBXT_6tCa-FE0JPUWTi-nrNbwqJEesZxVM9TL26I4I9yN5itK5qGfTo3DvEoJjGzZW9xLDw"
}
response = requests.get(url, headers=headers)
print(response.text)

# %% [markdown]
# ## Step 4 Generate Background Music

# %%
from pydub import AudioSegment
from pydub.generators import Sine, Square

# Set the tempo and duration of the beat
tempo = 120  # beats per minute
duration = 4000  # milliseconds

# Generate the audio signal for each instrument
kick = Sine(60).to_audio_segment(duration=duration, volume=-12)
snare = Sine(90).to_audio_segment(duration=duration, volume=-12)
square = Square(440).to_audio_segment(duration=duration, volume=-12)

# Create a new audio segment to hold the beat
beat = AudioSegment.silent(duration=duration)

# Add the audio signal for each instrument to the beat
beat = beat.overlay(kick, position=0)
beat = beat.overlay(snare, position=1000)
beat = beat.overlay(square, position=2000)

# Export the beat as an MP3 file
beat.export("my_beat.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='my_beat.mp3'>

# %% [markdown]
# ## Step 5 Edit Video
#
# We now have
# - video
# - audio
# - an animation
# - background music
#
# Let's stitch it all together with the ShotStack API

# %%
from shotstack_sdk.model.soundtrack import Soundtrack
import shotstack_sdk as shotstack
from shotstack_sdk.api import edit_api
from shotstack_sdk.model.video_asset import VideoAsset
from shotstack_sdk.model.image_asset import ImageAsset

from shotstack_sdk.model.clip import Clip
from shotstack_sdk.model.track  import Track
from shotstack_sdk.model.timeline import Timeline
from shotstack_sdk.model.output import Output
from shotstack_sdk.model.edit import Edit




host = 'https://api.shotstack.io/stage'
configuration = shotstack.Configuration(host = host)

configuration.api_key['DeveloperKey'] = 'vbtcV58kDfEmmV3rjHiW2lhpJotafLIaAbbeSH3j'

with shotstack.ApiClient(configuration) as api_client:
    api_instance = edit_api.EditApi(api_client)

    video_asset = VideoAsset(
        src = 'https://d-id-talks-prod.s3.us-west-2.amazonaws.com/google-oauth2%7C108165495726617830964/tlk_C6m8WkEyXUDBd77AnTELN/rkDNaTq.mp4?AWSAccessKeyId=AKIA5CUMPJBIK65W6FGA&Expires=1677005175&Signature=bSinboWpYBRGmd4OjuzlrV6rqok%3D',
    )

   #soundtrack = Soundtrack(
   #   src = 'https://s3-ap-southeast-2.amazonaws.com/shotstack-assets/music/disco.mp3',
   #   effect = 'fadeIn',
   #   volume = 1.0
#)

    image_asset = ImageAsset(
        src = 'https://i.imgur.com/8nLFCVP.png',
    )
    video_clip = Clip(
        asset = video_asset,
        start = 0.0,
        length = 8.0
    )

    image_clip = Clip(
        asset = image_asset,
        start = 4.0,
        length = 4.0,
        fit = 'crop',
        scale = 0.0,
        position = 'center',
        opacity = 1.0,
)

    track = Track(clips=[video_clip, image_clip])

    timeline = Timeline(tracks=[track])


    output = Output(
        format = 'mp4',
        resolution = 'sd'
    )

    edit = Edit(
        timeline = timeline,
        output = output
    )

    try:
        api_response = api_instance.post_render(edit)
        print(f"{api_response['response']['id']}")
    except Exception as e:
        print(f"Unable to resolve API call: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fea1f8a5e06c> in <module>
# ----> 1 from shotstack_sdk.model.soundtrack import Soundtrack
#       2 import shotstack_sdk as shotstack
#       3 from shotstack_sdk.api import edit_api
#       4 from shotstack_sdk.model.video_asset import VideoAsset
#       5 from shotstack_sdk.model.image_asset import ImageAsset
#
# ModuleNotFoundError: No module named 'shotstack_sdk'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Once we sent the edited video to Shotstack, we wait for it to render.
# Then we can pull the edited video MP4 from the server

# %%
import shotstack_sdk as shotstack
from shotstack_sdk.api import edit_api

host = 'https://api.shotstack.io/stage'
configuration = shotstack.Configuration(host = host)

configuration.api_key['DeveloperKey'] = 'vbtcV58kDfEmmV3rjHiW2lhpJotafLIaAbbeSH3j'

with shotstack.ApiClient(configuration) as api_client:
    api_instance = edit_api.EditApi(api_client)

    id = 'de58c33d-d734-4539-8caa-73d27e4401f5'

    try:
        api_response = api_instance.get_render(id, data=False, merged=True)
        status = api_response['response']['status']

        if status == 'done':
            print(f"{api_response['response']['url']}")
    except Exception as e:
        print(f"Unable to resolve API call: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f58748bdf03b> in <module>
# ----> 1 import shotstack_sdk as shotstack
#       2 from shotstack_sdk.api import edit_api
#       3
#       4 host = 'https://api.shotstack.io/stage'
#       5 configuration = shotstack.Configuration(host = host)
#
# ModuleNotFoundError: No module named 'shotstack_sdk'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Step 6 Post to Youtube
#
# In order to post this video to Youtube, we'll do 2 steps
# 1. Create a Google Sheet named "KatherineAI"
# 2. Add a new row to this sheet with the ShotStack URL

# %%
## Create a Google Sheet named "KatherineAI", if one doesn't already exist.
## Add a new row to this sheet with the URL
## That's it! We'll call that Google Sheet from Google's App Script Service
## in order to auto post it to Youtube. Why? Because Google Auth is difficult
## and finnicky.

from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
SAMPLE_RANGE_NAME = 'Class Data!A2:E'


def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        service = build('sheets', 'v4', credentials=creds)

        # Call the Sheets API
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=SAMPLE_RANGE_NAME).execute()
        values = result.get('values', [])

        if not values:
            print('No data found.')
            return

        print('Name, Major:')
        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
            print('%s, %s' % (row[0], row[4]))
    except HttpError as err:
        print(err)


if __name__ == '__main__':
    main()
# [END sheets_quickstart]

# %% [markdown]
# Now for the last step, posting to youtube.
#
# 1. Go to https://script.google.com/
# 2. paste in the code below to run this as an 'app script'
# 3. Enable the Google Sheets and Youtube API
# 4. Set a daily trigger to run it once a day.
# 5. Use all this python code in your own flask app with a scheduler to run once daily

# %%
function myFunction() {

 print('hello')

 // Open a document by ID.
  var doc = DocumentApp.openById('DOCUMENT_ID_GOES_HERE');

}

function getGeneratedVideoURLs() {
  var sheet = SpreadsheetApp.getActiveSheet();
  var data = sheet.getDataRange().getValues();
  for (var i = 0; i < data.length; i++) {
    Logger.log('Generated Video URL: ' + data[i][0]);
  }
}

function upload()
{ try
  { var video = UrlFetchApp.fetch("https://talks-api-results.d-id.com/google-oauth2%7C108165495726617830964%2Ftlk_ZmLjusNgduqfXPxDDti-p%2Fimage.mp4");
  YouTube.Videos.insert(
    { snippet:
      { title: "AI Video by Katherine", description: "This is a video about Katherine AI", tags: ["funny"] }, status: { privacyStatus: "private", },
    }, "snippet,status", video);

  return ContentService.createTextOutput("done") }
  catch (err) {
    return ContentService.createTextOutput(err.message) }
}


upload();
